# %% [markdown]
# # Pydantic models FastAPI Glossary

# %%
import pandas as pd

# EDA
#load json file into DF:
df = pd.read_json("../../data/fastapi_glossary.json")
df.head()
# Out:
#    id              word                                            meaning
# 0   1    path parameter  Request parameters embedded in the URL path to...
# 1   2  endpoint (route)  A URL path in the API that accepts HTTP reques...
# 2   3   query parameter  Additional key–value pairs after ? in the URL,...
# 3   4      request body  Data sent with POST/PUT/PATCH requests, usuall...
# 4   5           uvicorn  ASGI web server used to run FastAPI apps. Comm...

# %%
df.describe().T
# Out:
#     count  mean     std  min   25%  50%    75%   max
# id   14.0   7.5  4.1833  1.0  4.25  7.5  10.75  14.0

# %%
df["word"].value_counts()
# Out:
# word
# path parameter                1
# endpoint (route)              1
# query parameter               1
# request body                  1
# uvicorn                       1
# %20                           1
# Field (pydantic)              1
# DTO                           1
# client                        1
# schema                        1
# Depends()                     1
# payload                       1
# field_validator (pydantic)    1
# model_validator               1
# Name: count, dtype: int64

# %%
len(df["word"])
# Out:
# 14

# %% [markdown]
# ### deserialize json object into pydantic model

# %%
df["word"]
# Out:
# 0                 path parameter
# 1               endpoint (route)
# 2                query parameter
# 3                   request body
# 4                        uvicorn
# 5                            %20
# 6               Field (pydantic)
# 7                            DTO
# 8                         client
# 9                         schema
# 10                     Depends()
# 11                       payload
# 12    field_validator (pydantic)
# 13               model_validator
# Name: word, dtype: object

# %%
df.keys().drop("id")
# Out:
# Index(['word', 'meaning'], dtype='object')

# %%
df
# Out:
#     id                        word  \
# 0    1              path parameter
# 1    2            endpoint (route)
# 2    3             query parameter
# 3    4                request body
# 4    5                     uvicorn
# 5    6                         %20
# 6    7            Field (pydantic)
# 7    8                         DTO
# 8    9                      client
# 9   10                      schema
# 10  11                   Depends()
# 11  12                     payload
# 12  13  field_validator (pydantic)
# 13  14             model_validator
#
#                                               meaning
# 0   Request parameters embedded in the URL path to...
# 1   A URL path in the API that accepts HTTP reques...
# 2   Additional key–value pairs after ? in the URL,...
# 3   Data sent with POST/PUT/PATCH requests, usuall...
# 4   ASGI web server used to run FastAPI apps. Comm...
# 5   URL-encoded space character used in URL paths ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       14 non-null     int64
#  1   word     14 non-null     object
#  2   meaning  14 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
from pydantic import BaseModel

class FastAPI_Glossary(BaseModel):
    id: int
    word: str
    meaning: str

with open("../../data/fastapi_glossary.json") as f:
    data = json.load(f)

glossary = FastAPI_Glossary.model_validate(df)
glossary
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[35], line 8
#       5     word: str
#       6     meaning: str
# ----> 8 glossary = FastAPI_Glossary.model_validate({"id": int, "word": str, "meaning":str})
#       9 glossary
#
# File ~/Desktop/NBI_year_2/Repo/AI_Engineering_OPA24_Susanna_Rokka/.venv/lib/python3.12/site-packages/pydantic/main.py:705, in BaseModel.model_validate(cls, obj, strict, from_attributes, context, by_alias, by_name)
#     699 if by_alias is False and by_name is not True:
#     700     raise PydanticUserError(
#     701         'At least one of `by_alias` or `by_name` must be set to True.',
#     702         code='validate-by-alias-and-name-false',
#     703     )
# --> 705 return cls.__pydantic_validator__.validate_python(
#     706     obj, strict=strict, from_attributes=from_attributes, context=context, by_alias=by_alias, by_name=by_name
# ...
