# %%
import pandas as pd
# uv pip install openpyxl

df = pd.read_excel("../../../data/resultat-ansokningsomgang-2024.xlsx", sheet_name="Tabell 3", header=5)
df.head()
# Out:
#   Utbildningsområde SUN5 inriktning                   SUN5 inriktning namn  \
# 0           Data/IT           481ab  Utbildningar till programmerare, spel
# 1           Data/IT           481ab  Utbildningar till programmerare, spel
# 2           Data/IT           481ab  Utbildningar till programmerare, spel
# 3           Data/IT           481ab  Utbildningar till programmerare, spel
# 4           Data/IT           481ab  Utbildningar till programmerare, spel
#
#                                 Utbildningsnamn    Beslut   Diarienummer  \
# 0                                 AI Programmer    Avslag  MYH 2024/3742
# 1  Forsbergs, Spelutvecklare – Game Programming    Avslag  MYH 2024/4174
# 2    Futuregames Game Programmer Specialization    Avslag  MYH 2024/3029
# 3                               Game Programmer    Avslag  MYH 2024/3425
# 4                             Spelprogrammerare  Beviljad  MYH 2024/3852
#
#   Flera kommuner  Antal kommuner             Län          Kommun  ...  \
# ...

# %%
df.shape
# Out:
# (1272, 28)

# %%
df.columns
# Out:
# Index(['Utbildningsområde', 'SUN5 inriktning', 'SUN5 inriktning namn',
#        'Utbildningsnamn', 'Beslut', 'Diarienummer', 'Flera kommuner',
#        'Antal kommuner', 'Län', 'Kommun', 'YH-poäng', 'Studieform',
#        'Studietakt %', 'Typ av examen', 'SeQF nivå', 'Smalt yrkesområde',
#        'Utbildningsanordnare administrativ enhet', 'Huvudmannatyp',
#        'Sökta utbildningsomgångar', 'Beviljade utbildningsomgångar',
#        'Sökta platser per utbildningsomgång', 'Sökta platser totalt',
#        'Beviljade platser utbildningsomgång 1',
#        'Beviljade platser utbildningsomgång 2',
#        'Beviljade platser utbildningsomgång 3',
#        'Beviljade platser utbildningsomgång 4',
#        'Beviljade platser utbildningsomgång 5', 'Beviljade platser totalt'],
#       dtype='object')

# %%
df["Beslut"].value_counts()
# Out:
# Beslut
# Avslag      928
# Beviljad    344
# Name: count, dtype: int64

# %%
df["Kommun"].value_counts()
# Out:
# Kommun
# Flera kommuner    292
# Stockholm         248
# Göteborg          157
# Malmö              86
# Linköping          32
#                  ...
# Mörbylånga          1
# Haninge             1
# Katrineholm         1
# Kungsbacka          1
# Leksand             1
# Name: count, Length: 104, dtype: int64

# %%
ax = df["Utbildningsområde"].value_counts().plot(kind= "barh")
ax.invert_yaxis()

# %%
ax = df.query("Beslut == 'Beviljad'")["Utbildningsområde"].value_counts().plot(kind = "barh")
ax.invert_yaxis()

# %%
df["Utbildningsanordnare administrativ enhet"].unique()
# Out:
# array(['Futuregames Umeå', 'Forsbergs Skola', 'Futuregames Karlstad',
#        'Hyper Island Program AB - Karlskrona', 'TGA Utbildning AB',
#        'Nackademin AB', 'KYH AB Stockholm', 'KYH AB Göteborg',
#        'KYH AB Malmö', 'Plushögskolan AB - Teknikhögskolan',
#        'IT-Högskolan Stockholm AB', 'IT-Högskolan Sverige AB',
#        'JENSEN Education School AB',
#        'Kunskapsgruppen Yrkeshögskola Sverige AB', 'Chas Academy AB',
#        'Handelsakademin i Göteborg AB', 'Företagsuniversitetet AB',
#        'Yrkeshögskola Campus Mölndal', 'Hermods AB Stockholm', 'AVT AB',
#        'Företagsekonomiska Institutet 1888 AB',
#        'Stiftelsen Stockholms Tekniska Institut', 'YH Akademin AB',
#        'KYH AB', 'Grit Academy', 'Skill Utbildning AB',
#        'Folkuniversitetet Kursverksamheten vid Göteborgs universitet',
#        'EC Utbildning AB Örebro', 'EC Utbildning AB Stockholm',
#        'EC Utbildning AB Göteborg', 'IHM Business School AB Stockholm',
# ...

# %%
df.query("`Utbildningsanordnare administrativ enhet`=='Handelsakademin i Göteborg AB'")
# Out:
#                   Utbildningsområde SUN5 inriktning  \
# 22                          Data/IT           481ac
# 23                          Data/IT           481ac
# 50                          Data/IT           481ac
# 873  Samhällsbyggnad och byggteknik           582ca
# 956  Samhällsbyggnad och byggteknik           582gb
#
#                                   SUN5 inriktning namn  \
# 22   Utbildningar inom systemhantering och programm...
# 23   Utbildningar inom systemhantering och programm...
# 50   Utbildningar inom systemhantering och programm...
# 873      Utbildningar till konstruktör/projektör, bygg
# 956             Utbildningar till anläggningsprojektör
#
#                                        Utbildningsnamn    Beslut  \
# 22                  Backend Developer inriktning Cloud  Beviljad
# 23                  Backend Developer inriktning Cloud    Avslag
# 50                    Mjukvaruutvecklare inriktning AI    Avslag
# ...

# %%
school = df.query('Handelsakademin i Göteborg AB')

df.query ("`Utbildningsanordnare administrativ enhet`== @school")
# Out:
# Traceback (most recent call last):
#
#   File ~/Desktop/NBI_year_2/Repo/AI_Engineering_OPA24_Susanna_Rokka/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[31], line 1
#     school = df.query('Handelsakademin i Göteborg AB')
#
#   File ~/Desktop/NBI_year_2/Repo/AI_Engineering_OPA24_Susanna_Rokka/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4828 in query
#     res = self.eval(expr, **kwargs)
#
#   File ~/Desktop/NBI_year_2/Repo/AI_Engineering_OPA24_Susanna_Rokka/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4954 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File ~/Desktop/NBI_year_2/Repo/AI_Engineering_OPA24_Susanna_Rokka/.venv/lib/python3.12/site-packages/pandas/core/computation/eval.py:339 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
# ...
