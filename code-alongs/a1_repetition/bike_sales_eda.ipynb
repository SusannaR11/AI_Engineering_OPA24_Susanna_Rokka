# %% [markdown]
# # Exploratory Data Analysis (EDA) on Bike Sales Dataset

# %%
import pandas as pd

df = pd.read_csv("../../data/Europe_Bike_Sales.csv", index_col=0, parse_dates=True)
df.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df.loc["2013"]
# Out:
#             Day      Month  Year  Customer_Age             Age_Group  \
# Date
# 2013-11-26   26   November  2013            19           Youth (<25)
# 2013-07-30   30       July  2013            32  Young Adults (25-34)
# 2013-07-15   15       July  2013            34  Young Adults (25-34)
# 2013-08-02    2     August  2013            29  Young Adults (25-34)
# 2013-09-02    2  September  2013            29  Young Adults (25-34)
# ...         ...        ...   ...           ...                   ...
# 2013-12-10   10   December  2013            20           Youth (<25)
# 2013-10-04    4    October  2013            20           Youth (<25)
# 2013-10-02    2    October  2013            34  Young Adults (25-34)
# 2013-07-08    8       July  2013            29  Young Adults (25-34)
# 2013-12-28   28   December  2013            41        Adults (35-64)
#
#            Customer_Gender         Country             State Product_Category  \
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               113036 non-null  int64
#  1   Month             113036 non-null  object
#  2   Year              113036 non-null  int64
#  3   Customer_Age      113036 non-null  int64
#  4   Age_Group         113036 non-null  object
#  5   Customer_Gender   113036 non-null  object
#  6   Country           113036 non-null  object
#  7   State             113036 non-null  object
#  8   Product_Category  113036 non-null  object
#  9   Sub_Category      113036 non-null  object
#  10  Product           113036 non-null  object
#  11  Order_Quantity    113036 non-null  int64
#  12  Unit_Cost         113036 non-null  int64
#  13  Unit_Price        113036 non-null  int64
#  14  Profit            113036 non-null  int64
# ...

# %%
df.shape # Hur många kolumner, hur många rader
# Out:
# (113036, 18)

# %%
df.columns # vad heter kolumnerna
# Out:
# Index(['Day', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender',
#        'Country', 'State', 'Product_Category', 'Sub_Category', 'Product',
#        'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost',
#        'Revenue', 'Is_Bike'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
df.groupby("Country")["Revenue"].sum().sort_values(ascending=True)
# Out:
# Country
# Canada             7935738
# France             8432872
# Germany            8978596
# United Kingdom    10646196
# Australia         21302059
# United States     27975547
# Name: Revenue, dtype: int64

# %%
df.groupby("Customer_Gender")["Revenue"].mean()
# Out:
# Customer_Gender
# F    766.310924
# M    743.164512
# Name: Revenue, dtype: float64

# %%
(df['Revenue'] - df['Cost']).equals(df['Profit'])
# Out:
# True

# %%
df[['Unit_Cost','Unit_Price','Profit','Cost','Revenue']].describe()
# Out:
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# 25%         2.000000       5.000000      29.000000      28.000000
# 50%         9.000000      24.000000     101.000000     108.000000
# 75%        42.000000      70.000000     358.000000     432.000000
# max      2171.000000    3578.000000   15096.000000   42978.000000
#
#              Revenue
# count  113036.000000
# mean      754.370360
# std      1309.094674
# min         2.000000
# 25%        63.000000
# 50%       223.000000
# 75%       800.000000
# max     58074.000000

# %%
# Group by product category
category_sales = df.groupby("Product_Category")["Order_Quantity"].sum().reset_index()

# Sort it
category_sales = category_sales.sort_values("Order_Quantity", ascending=False)

display(category_sales)
# Out:
#   Product_Category  Order_Quantity
# 0      Accessories         1054162
# 2         Clothing          254743
# 1            Bikes           36411

# %%
df['Is_Bike'] = df['Product_Category'].apply(lambda x: "Bike" if x=="Bikes" else "Other")

bike_vs_other = df.groupby("Is_Bike")["Order_Quantity"].sum().reset_index()
bike_vs_other
# Out:
#   Is_Bike  Order_Quantity
# 0    Bike           36411
# 1   Other         1308905

# %%
revenue_per_category = df.groupby("Product_Category")["Revenue"].sum()
print(revenue_per_category)
# Out:
# Product_Category
# Accessories    15117992
# Bikes          61782134
# Clothing        8370882
# Name: Revenue, dtype: int64

# %%
product_revenue =df.groupby(["Product", "Product_Category", "Order_Quantity", "Profit"])["Revenue"].sum().reset_index()
product_revenue=product_revenue.sort_values("Revenue", ascending=False)
display(product_revenue.head(10))
# Out:
#                       Product Product_Category  Order_Quantity  Profit  \
# 8512         Road-150 Red, 52            Bikes               1    1335
# 6740  Mountain-200 Silver, 42            Bikes               1    1008
# 8596         Road-150 Red, 62            Bikes               1     942
# 6650   Mountain-200 Black, 46            Bikes               1     997
# 6696  Mountain-200 Silver, 38            Bikes               1    1008
# 6554   Mountain-200 Black, 38            Bikes               1     951
# 8558         Road-150 Red, 56            Bikes               1    1335
# 8525         Road-150 Red, 52            Bikes               2    2671
# 6739  Mountain-200 Silver, 42            Bikes               1     961
# 8467         Road-150 Red, 48            Bikes               1    1335
#
#       Revenue
# 8512   557454
# 6740   550308
# 8596   491854
# 6650   456547
# 6696   400224
# 6554   354683
# 8558   354106
# 8525   329611
# 6739   329596
# 8467   315540

# %%
calc_profit = (df["Unit_Price"] - df["Unit_Cost"]) * df["Order_Quantity"]
df["Profit"].equals(calc_profit)   # should be False
(df["Profit"] - calc_profit).describe()  # see the difference
# Out:
# count    113036.000000
# mean        -87.629693
# std         207.863120
# min      -11062.000000
# 25%         -73.000000
# 50%         -15.000000
# 75%          -3.000000
# max           0.000000
# dtype: float64

# %%
monthly_sales=df.groupby("Month")["Revenue"].sum().reset_index()
monthly_sales = monthly_sales.sort_values("Revenue", ascending=False)
display(monthly_sales)
# Out:
#         Month  Revenue
# 2    December  9086931
# 6        June  9043008
# 8         May  8836763
# 0       April  7602750
# 7       March  7347164
# 4     January  7005895
# 3    February  6834583
# 9    November  6244298
# 10    October  5995079
# 11  September  5841885
# 5        July  5721459
# 1      August  5711193

# %%
df.columns #explore which columns exist in dataset
# Out:
# Index(['Day', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender',
#        'Country', 'State', 'Product_Category', 'Sub_Category', 'Product',
#        'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost',
#        'Revenue', 'Is_Bike'],
#       dtype='object')

# %% [markdown]
# - unit - inköpspris
# - unit_price - säljpris per kost
# - profit - vinst på hela raden
# - rad - en beställning på en produkt
# - cost - order_quantity * unit_cost (kostnad för hela raden)
# - revenue - intäkt (pengar man får in för raden ev. ex rabatter och skatt)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 113036 entries, 2013-11-26 to 2016-03-04
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               113036 non-null  int64
#  1   Month             113036 non-null  object
#  2   Year              113036 non-null  int64
#  3   Customer_Age      113036 non-null  int64
#  4   Age_Group         113036 non-null  object
#  5   Customer_Gender   113036 non-null  object
#  6   Country           113036 non-null  object
#  7   State             113036 non-null  object
#  8   Product_Category  113036 non-null  object
#  9   Sub_Category      113036 non-null  object
#  10  Product           113036 non-null  object
#  11  Order_Quantity    113036 non-null  int64
#  12  Unit_Cost         113036 non-null  int64
#  13  Unit_Price        113036 non-null  int64
#  14  Profit            113036 non-null  int64
# ...

# %%
df.shape
# Out:
# (113036, 18)

# %%
df["Product_Category"].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
df["Country"].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
df.head()
# Out:
#             Day     Month  Year  Customer_Age       Age_Group Customer_Gender  \
# Date
# 2013-11-26   26  November  2013            19     Youth (<25)               M
# 2015-11-26   26  November  2015            19     Youth (<25)               M
# 2014-03-23   23     March  2014            49  Adults (35-64)               M
# 2016-03-23   23     March  2016            49  Adults (35-64)               M
# 2014-05-15   15       May  2014            47  Adults (35-64)               F
#
#               Country             State Product_Category Sub_Category  \
# Date
# 2013-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2015-11-26     Canada  British Columbia      Accessories   Bike Racks
# 2014-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2016-03-23  Australia   New South Wales      Accessories   Bike Racks
# 2014-05-15  Australia   New South Wales      Accessories   Bike Racks
#
# ...

# %%
df["Age_Group"].value_counts()
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
df.describe().T.drop("count", axis=1) # T for transponering - rader blir kolumner, kolumner blir rader
# data chaining. en ny dataframe på en df. 'method chaining'
# method chaining -> because it returns a dataframe for each method call
# in implementation of each method it returns itself
# right click on 'describe' -> go to implementations' for source code
# Out:
#                        mean          std     min     25%     50%     75%  \
# Day               15.665753     8.781567     1.0     8.0    16.0    23.0
# Year            2014.401739     1.272510  2011.0  2013.0  2014.0  2016.0
# Customer_Age      35.919212    11.021936    17.0    28.0    35.0    43.0
# Order_Quantity    11.901660     9.561857     1.0     2.0    10.0    20.0
# Unit_Cost        267.296366   549.835483     1.0     2.0     9.0    42.0
# Unit_Price       452.938427   922.071219     2.0     5.0    24.0    70.0
# Profit           285.051665   453.887443   -30.0    29.0   101.0   358.0
# Cost             469.318695   884.866118     1.0    28.0   108.0   432.0
# Revenue          754.370360  1309.094674     2.0    63.0   223.0   800.0
#
#                     max
# Day                31.0
# Year             2016.0
# Customer_Age       87.0
# Order_Quantity     32.0
# Unit_Cost        2171.0
# Unit_Price       3578.0
# Profit          15096.0
# Cost            42978.0
# ...

# %% [markdown]
# ## Country and Profit using Pandas

# %%
df[["Country", "Profit"]].groupby(["Country"]).mean(numeric_only=True).sort_values(by="Profit", ascending=False).reset_index()
# Out:
#           Country      Profit
# 0  United Kingdom  324.071439
# 1         Germany  302.756803
# 2       Australia  283.089489
# 3   United States  282.447687
# 4          Canada  262.187615
# 5          France  261.891435

# %% [markdown]
# ## Country and Profit using Duckdb

# %%
import duckdb

df_profit = duckdb.query(
    """
SELECT 
    country, 
    SUM(profit) AS Total_profit,
    MEAN(profit) AS Avg_profit,
    MEDIAN(profit) AS Median_profit,
FROM df
GROUP BY
    country
ORDER BY
    Total_profit DESC,
    Avg_profit DESC
    """

).df()

df_profit
# Out:
#           Country  Total_profit  Avg_profit  Median_profit
# 0   United States    11073644.0  282.447687           87.0
# 1       Australia     6776030.0  283.089489          114.0
# 2  United Kingdom     4413853.0  324.071439          134.0
# 3          Canada     3717296.0  262.187615           83.0
# 4         Germany     3359995.0  302.756803          134.0
# 5          France     2880282.0  261.891435           99.0

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, figsize= (12, 6), dpi=150)

ax.bar(x=df_profit["Country"], height=df_profit["Total_profit"])
ax.set(xlabel = "Country", ylabel= "Total profit", title = "Total profit per country")

fig.savefig("profit_per_country.png")
